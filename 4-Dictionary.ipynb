# %%
# key - value pairing

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [100,150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100,"apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary[0] #Key Error alıyoruz çünkü index çağıramazsın.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fitness_dictionary[0] #Key Error alıyoruz çünkü index çağıramazsın.
#
# KeyError: 0

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary.keys() #Sadece anahtarları almak için kullanırım.
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values() #Sadece değerleri verir.
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
type(fitness_dictionary.keys())
# Out:
# dict_keys

# %%
valueList = list(fitness_dictionary.values())

# %%
valueList
# Out:
# [100, 150]

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300 #Ekstra fonksiyon olmadan dictionary'e bir şey ekleyebilirsin.

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
help(fitness_dictionary.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
fitness_dictionary.get("appl",0)
# Out:
# 0

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
my_dictionary = {100:"a",200:"b",300:"c"}

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_dictionary[200]
# Out:
# 'b'

# %%
my_dictionary = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
my_dictionary["key1"]
# Out:
# 'value1'

# %%
my_mixed_dictionary = {"key1":100,"key2":3.14,"key3":[10,20,30]}

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
# Tek satırda 200 sayısını al.
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
# Tek satırda 40 sayısını al
last_dictionary["k2"][-2]
# Out:
# 40
