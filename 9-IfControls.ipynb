# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y > x
# Out:
# False

# %%
y < x
# Out:
# True

# %%
y = 5

# %%
x >= 5
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.001
# Out:
# False

# %%
x = 10
y = 8

# %%
x
# Out:
# 10

# %%
y
# Out:
# 8

# %%
x = y #x y'nin değerine eşit olmuş olur. 8 olur yani

# %%
y
# Out:
# 8

# %%
x
# Out:
# 8

# %%
x = 10

# %%
x == y #eşit midir diye kontrol ederiz
# Out:
# False

# %%
x != y #eşit değil midir diye kontrol ederiz
# Out:
# True

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
2 > 1 and 3 > 2 #2 koşulda doğru olmak zorunda. and operatörüyle
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
10 in (10,20,30)
# Out:
# True

# %%
type(10 in (10,20,30))
# Out:
# bool

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":  #batman olduğu sürece çalışır
    #indentation
    print("batmannn")
    print("emirhan kandemir")
print("hello python")
# Out:
# batmannn
# emirhan kandemir
# hello python

# %%
my_superhero = "Superman"

# %%
my_superhero == "Batman"
# Out:
# False

# %%
my_superhero == "Superman"
# Out:
# True

# %%
if my_superhero == "Batman": #value vermedi çünkü doğru değil yukarıda değiştirdik
    print("batmannn")
    print("emirhan kandemir")
##########----------------######### sola çekilen bu kısım if bloğuna dahil değil
print("hello python")
# Out:
# hello python

# %%
if 3 > 4:
    print("hello world")
    print("emir")

# %%
my_superhero = input("enter superhero: ")

# %%
if my_superhero == "Superman": #Eğer benim süperkahramanım yukarıdaki inputta buysa yazdır
    print("superman")
elif my_superhero == "Batman": 
    print("batman")
elif my_superhero == "Aquaman":
    print("aquaman")
elif my_superhero == "Ironman":
    print("ironman")
else: #Yukarıdakilerin hiçbirine uygun değilse demek
    print(":(")
# Out:
# :(

# %%
my_age = 17

# %%
if my_age < 18:
    print("age < 18")
elif my_age > 18 and my_age <= 30:
    print("18 - age - 30")
elif my_age > 30 and my_age <=40:
    print("30 - age - 40")
else:
    print("age > 40")
# Out:
# age < 18

# %%
my_superhero = input("enter superhero: ") #Spider Man verdi diyelim
                                          #Üzülen surat verdi bıraktım çünkü Batman yazdım

# %%
my_superhero_list = ["Spider Man", "Iron Man","Thor","Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :(
