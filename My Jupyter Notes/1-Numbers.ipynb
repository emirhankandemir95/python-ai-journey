# %%
3+5
# Out:
# 8

# %%
4*3
# Out:
# 12

# %%
900 / 4
# Out:
# 225.0

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
5 * 5 * 5 * 5 * 5
# Out:
# 3125

# %%
5*5*5*5*5
# Out:
# 3125

# %%
4+2
# Out:
# 6

# %%
60/2
# Out:
# 30.0

# %%
60*5
# Out:
# 300

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age * 5
# Out:
# 250

# %%
age / 2
# Out:
# 25.0

# %%
aget * 3 #NameError alırsın tanımlamadığın bir değişken olduğu için.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 aget * 3 #NameError alırsın tanımlamadığın bir değişken olduğu için.
#
# NameError: name 'aget' is not defined

# %%
# data type (Veri Tipi)

# %%
# çarparken toplarken çıkartırkan Integer yani int değerler alırlar. Ama bölerken tam bölmesini istemez isen / float olarak tanımlanır değer

# %%
type(10)         #parantez içine yazdığın verinin hangi veri tipine ait olduğunu yazar

# %%
type(10*3)

# %%
type(age*5)

# %%
#int -> integer

# %%
type(-1000)

# %%
x = -100

# %%
type(x)

# %%
type(3.14)

# %%
#float -> floating point (kesirli sayılar için oluşturulmuş veri tipi)

# %%
pi = 3.14

# %%
pi*2

# %%
x + pi

# %%
x / pi

# %%
x = 10

# %%
x = 20

# %%
x+10

# %%
myFloat = 1.34432423

# %%
type(myFloat)

# %%
# myFloat ya da my_float şeklinde yazmamızın sebebi tamamen okunaklı olması için. Yoksa myfloat şeklinde de yazabilirsin. 
#Bir sürü satır için okunaklı olması önemli

# %%
# camelCase 
# snake_case adlandırılır bunların (Genel Kültür bilmene gerek yok)

# %%
40 / 4

# %%
type(40/4)

# %%
40 / 9

# %%
40 / 13

# %%
4 / 2

# %%
4 / 3

# %%
# Bu arada bu sayılar Python'da geçerli yani böldüğünde float verir. Ama Java'da mesela 4 / 3 = 1 olur
# Java yazıyorsanız noktaları eklemeniz gerekir (Aklında BULUNSUN!)

# %%
4 * 2

# %%
4.0 - 2

# %%
type(4.0 - 2)

# %%
4.2 * 3 - 10

# %%
2 - 10 * 2

# %%
# PEMDAS methodundan kaynaklı matematik tamamen üst satır

# %%
2 ** 9 # 2'nin 9. üssü

# %%
10 % 3 # remainder yani 10'u 3'e böldüğünde kaç kaldığını gösterir

# %%
10 % 2

# %%
10 % 4

# %%
# ileride bir sayının tek mi çift mi olduğunu anlamak için remainder kullanıyoruz !
