# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
myBoolean
# Out:
# True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean = False

# %%
myBoolean
# Out:
# False

# %%
type(myBoolean)
# Out:
# bool

# %%
# Eğer bu olursa şunu yap bu olursa bunu yapı koşul kontrollerini yapabilmek için önemli

# %%
5 > 3
# Out:
# True

# %%
3 < 5
# Out:
# True

# %%
3 > 5
# Out:
# False

# %%
2 < 1
# Out:
# False

# %%
# Değişken oluşturmak için gerekli olan bir şey değil. Kontrollerin sonucunda gelir.

# %%
# İnput al mesela bir variable ata ve bunu true ya da false mu diye check et  age 30 girdim
age = int(input("Yaşınızı Girin: "))
isTrue = age > 18
isTrue
# Out:
# True
