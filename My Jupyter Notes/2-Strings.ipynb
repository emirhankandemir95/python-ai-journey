# %%
hello world #Syntax Error verir çünkü program bunu anlayamaz. Syntax yani gramer gibi düşünebilirsin. Böyle bir şey yok ki benim dilimde diyor.
# Out:
#   Cell In[2], line 1
#     hello world #Syntax Error verir çünkü program bunu anlayamaz. Syntax yani gramer gibi düşünebilirsin. Böyle bir şey yok ki benim dilimde diyor.
#           ^
# SyntaxError: invalid syntax

# %%
"hello world"
# Out:
# 'hello world'

# %%
print() # Fonksiyondur. Pythonda tanımlıdır.

# %%
print("hello python")
# Out:
# hello python

# %%
# Bu bir kod değil bu bir sayı değil bu bir metin desin diye "" veya ''

# %%
name = "atıl"

# %%
type(name) #String yani str
# Out:
# str

# %%
"atil restaurant"
# Out:
# 'atil restaurant'

# %%
'atil restaurant'
# Out:
# 'atil restaurant'

# %%
"atil's restaurant"
# Out:
# "atil's restaurant"

# %%
'atil's restarunt' #Yine syntax error veriyor. Çünkü çift tırnak ile yazmadık. ama birisine ait bir şeyi tek tırnakla yazarsan üstten apostrof
#kullanmak istediğimizde kodu 'atil's s den önce bir string var gibi algılar.
# Out:
#   Cell In[14], line 1
#     'atil's restarunt' #Yine syntax error veriyor. Çünkü çift tırnak ile yazmadık. ama birisine ait bir şeyi tek tırnakla yazarsan üstten apostrof
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name = "atil"

# %%
type(name)
# Out:
# str

# %%
name = "emirhan kandemir"

# %%
name.capitalize()
# Out:
# 'Emirhan kandemir'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
x = 10

# %%
x = 8

# %%
name
# Out:
# 'emirhan kandemir'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name.count("a")
# Out:
# 2

# %%
name.count("b")
# Out:
# 0

# %%
name.upper()
# Out:
# 'EMIRHAN KANDEMIR'

# %%
name.lower()
# Out:
# 'emirhan kandemir'

# %%
# Bazı fonksiyonlar içindeki değeri değiştirebilir. Bazıları sadece öyle gösterir.

# %%
x = 10
y = 5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
name
# Out:
# 'emirhan kandemir'

# %%
nameUpper = name.upper()

# %%
nameUpper #Fonksiyonu bir değişkene kaydettik. Bazen değişkene kaydetmek isteyebilirsin. name değişkenini değiştirmedik burada yeni bir değer
# Out:
# 'EMIRHAN KANDEMIR'

# %%
print(name.upper())
# Out:
# EMIRHAN KANDEMIR

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
# Return bir şeyi döndürmek yeni bir değer vermek dışına. Yeni bir değer veriyorsa içindekini değiştirmez. Ya da o bilgiyi kaydedeceksen kullan!

# %%
len(name) # length (uzunluk)
# Out:
# 16

# %%
print("emirhan kandemir")
# Out:
# emirhan kandemir

# %%
print("emirhan \nkandemir")
# Out:
# emirhan
# kandemir

# %%
# \n -> new line yani sonrasından gelen kısmı stringlerde aşağıda yazdırmak için kullanabilirsin

# %%
#escape characters

# %%
# \t -> tab

# %%
print("emirhan \tkandemir") # sanki tab tuşuna basmışsın gibi 4 boşluk ekliyor

# %% [markdown]
# ## index

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[0]
# Out:
# 'h'

# %%
myString[1]
# Out:
# 'e'

# %%
myString[11]
# Out:
# 'n'

# %%
myString[12] # 12 harf var ama index'te 0'dan başladığı için 12 - 1= 11 harf varmış gibi gözükür
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myString[12] # 12 harf var ama index'te 0'dan başladığı için 12 - 1= 11 harf varmış gibi gözükür
#
# IndexError: string index out of range

# %%
myString = "emirhan kandemir"

# %%
myString[0]
# Out:
# 'e'

# %%
myString[11]
# Out:
# 'd'

# %%
myString[15]
# Out:
# 'r'

# %%
len(myString)
# Out:
# 16

# %%
len(myString) - 1
# Out:
# 15

# %%
myName = "james hetfield"

# %%
myName[len(myName) - 1]
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %%
myName[-2] # Pythona özel bir durum -1 -2 gibi durumlar diğer dillerde len yazmak zorundasın!
# Out:
# 'l'

# %%
barcode = "ABCDE123123982"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[1]
# Out:
# 'B'

# %%
barcode[2]
# Out:
# 'C'

# %%
10 + 20
# Out:
# 30

# %%
"A" + "B" #Pythonda intleri toplar gibi stringleride toplayabiliriz yine pythona özel bir durum bu. Stringleri yan yana yazmaya çalışıyordur diyip
# Out:
# 'AB'

# %%
name = "emirhan"

# %%
surname = "kandemir"

# %%
fullname = name + " " + surname

# %%
fullname
# Out:
# 'emirhan kandemir'

# %%
fullname * 5 # 5 kere yan yana yazdırmak istiyor kolaylığıda sağlamış python yan yana yazmaya çalışıyor diyip çarpma işlemi yapıyor
# Out:
# 'emirhan kandemiremirhan kandemiremirhan kandemiremirhan kandemiremirhan kandemir'

# %%
100 * "a" # mesela a harfini 100 kere yan yana yazdırabildik burada
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
fullname / 5 # Yani TypeError alırsın çünkü integer bir işlem yaptırmak istedin bölme yapmaya çalıştın diyor
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 fullname / 5 # Yani TypeError alırsın çünkü integer bir işlem yaptırmak istedin bölme yapmaya çalıştın diyor
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
fullname - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 fullname - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ABC'

# %%
#slicing, starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
#barcode[#starting index:stopping index:stepping size]

# %%
barcode[3::] #3. indexten başla
# Out:
# 'DE123123982'

# %%
barcode[:3:] #3. indexe kadar
# Out:
# 'ABC'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::3]
# Out:
# 'AD228'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[3:5]
# Out:
# 'DE'

# %%
barcode[1:9:2]
# Out:
# 'BD13'

# %%
barcode[::-1] #barcode'u ters çevirdi
# Out:
# '289321321EDCBA'

# %%
name = "emirhan kandemir"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.

# %%
name.index("k")
# Out:
# 8

# %%
name.split()
# Out:
# ['emirhan', 'kandemir']

# %%
type(name.split())
# Out:
# list
